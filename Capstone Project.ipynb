# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests
import numpy as np  
#https://www1.nyc.gov/site/nypd/stats/crime-statistics/park-crime-stats.page

# %% [markdown]
#  ## Data downloads

# %%
# !wget -q -O 'url.xlsx' = 'https://www1.nyc.gov/assets/nypd/downloads/excel/crime_statistics/park-crime/nyc-park-crime-stats-q1-2015.xlsx'
crime_data_q1_2015 = pd.read_excel('url.xlsx')
# !wget -q -O 'url.xlsx' = 'https://www1.nyc.gov/assets/nypd/downloads/excel/crime_statistics/park-crime/nyc-park-crime-stats-q1-2016.xlsx'
crime_data_q1_2016 = pd.read_excel('url.xlsx')
# !wget -q -O 'url.xlsx' = 'https://www1.nyc.gov/assets/nypd/downloads/excel/crime_statistics/park-crime/nyc-park-crime-stats-q1-2017.xlsx'
crime_data_q1_2017 = pd.read_excel('url.xlsx')
# !wget -q -O 'url.xlsx' = 'https://www1.nyc.gov/assets/nypd/downloads/excel/crime_statistics/park-crime/nyc-park-crime-stats-q1-2018.xlsx'
crime_data_q1_2018 = pd.read_excel('url.xlsx')
# !wget -q -O 'url.xlsx' = 'https://www1.nyc.gov/assets/nypd/downloads/excel/crime_statistics/park-crime/nyc-park-crime-stats-q1-2019.xlsx'
crime_data_q1_2019 = pd.read_excel('url.xlsx')
# !wget -q -O 'url.xlsx' = 'https://www1.nyc.gov/assets/nypd/downloads/excel/crime_statistics/park-crime/nyc-park-crime-stats-q1-2020a.xlsx'
crime_data_q1_2020 = pd.read_excel('url.xlsx')
# !wget -q -O 'url.xlsx' = 'https://www1.nyc.gov/assets/nypd/downloads/excel/crime_statistics/park-crime/nyc-park-crime-stats-q2-2015.xlsx'
crime_data_q2_2015 = pd.read_excel('url.xlsx')
# !wget -q -O 'url.xlsx' = 'https://www1.nyc.gov/assets/nypd/downloads/excel/crime_statistics/park-crime/nyc-park-crime-stats-q2-2016.xlsx'
crime_data_q2_2016 = pd.read_excel('url.xlsx')
# !wget -q -O 'url.xlsx' = 'https://www1.nyc.gov/assets/nypd/downloads/excel/crime_statistics/park-crime/nyc-park-crime-stats-q2-2017.xlsx'
crime_data_q2_2017 = pd.read_excel('url.xlsx')
# !wget -q -O 'url.xlsx' = 'https://www1.nyc.gov/assets/nypd/downloads/excel/crime_statistics/park-crime/nyc-park-crime-stats-q2-2018.xlsx'
crime_data_q2_2018 = pd.read_excel('url.xlsx')
# !wget -q -O 'url.xlsx' = 'https://www1.nyc.gov/assets/nypd/downloads/excel/crime_statistics/park-crime/nyc-park-crime-stats-q2-2019.xlsx'
crime_data_q2_2019 = pd.read_excel('url.xlsx')
# !wget -q -O 'url.xlsx' = 'https://www1.nyc.gov/assets/nypd/downloads/excel/crime_statistics/park-crime/nyc-park-crime-stats-q2-2020.xlsx'
crime_data_q2_2020 = pd.read_excel('url.xlsx')
# !wget -q -O 'url.xlsx' = 'https://www1.nyc.gov/assets/nypd/downloads/excel/crime_statistics/park-crime/nyc-park-crime-stats-q3-2015.xlsx'
crime_data_q3_2015 = pd.read_excel('url.xlsx')
# !wget -q -O 'url.xlsx' = 'https://www1.nyc.gov/assets/nypd/downloads/excel/crime_statistics/park-crime/nyc-park-crime-stats-q3-2016.xlsx'
crime_data_q3_2016 = pd.read_excel('url.xlsx')
# !wget -q -O 'url.xlsx' = 'https://www1.nyc.gov/assets/nypd/downloads/excel/crime_statistics/park-crime/nyc-park-crime-stats-q3-2017.xlsx'
crime_data_q3_2017 = pd.read_excel('url.xlsx')
# !wget -q -O 'url.xlsx' = 'https://www1.nyc.gov/assets/nypd/downloads/excel/crime_statistics/park-crime/nyc-park-crime-stats-q3-2018.xlsx'
crime_data_q3_2018 = pd.read_excel('url.xlsx')
# !wget -q -O 'url.xlsx' = 'https://www1.nyc.gov/assets/nypd/downloads/excel/crime_statistics/park-crime/nyc-park-crime-stats-q3-2019.xlsx'
crime_data_q3_2019 = pd.read_excel('url.xlsx')
# !wget -q -O 'url.xlsx' = 'https://www1.nyc.gov/assets/nypd/downloads/excel/crime_statistics/park-crime/nyc-park-crime-stats-q3-2020.xlsx'
crime_data_q3_2020 = pd.read_excel('url.xlsx')
# !wget -q -O 'url.xlsx' = 'https://www1.nyc.gov/assets/nypd/downloads/excel/crime_statistics/park-crime/nyc-park-crime-stats-q4-2015.xlsx'
crime_data_q4_2015 = pd.read_excel('url.xlsx')
# !wget -q -O 'url.xlsx' = 'https://www1.nyc.gov/assets/nypd/downloads/excel/crime_statistics/park-crime/nyc-park-crime-stats-q4-2016.xlsx'
crime_data_q4_2016 = pd.read_excel('url.xlsx')
# !wget -q -O 'url.xlsx' = 'https://www1.nyc.gov/assets/nypd/downloads/excel/crime_statistics/park-crime/nyc-park-crime-stats-q4-2017.xlsx'
crime_data_q4_2017 = pd.read_excel('url.xlsx')
# !wget -q -O 'url.xlsx' = 'https://www1.nyc.gov/assets/nypd/downloads/excel/crime_statistics/park-crime/nyc-park-crime-stats-q4-2018.xlsx'
crime_data_q4_2018 = pd.read_excel('url.xlsx')
# !wget -q -O 'url.xlsx' = 'https://www1.nyc.gov/assets/nypd/downloads/excel/crime_statistics/park-crime/nyc-park-crime-stats-q4-2019.xlsx'
crime_data_q4_2019 = pd.read_excel('url.xlsx')
# !wget -q -O 'url.xlsx' = 'https://www1.nyc.gov/assets/nypd/downloads/excel/crime_statistics/park-crime/nyc-park-crime-stats-q4-2020.xlsx'
crime_data_q4_2020 = pd.read_excel('url.xlsx')

# %% [markdown]
# ## DataFrame pre-processing

# %%
for i in range(1,5):
    for j in range(2016,2021):
        
        if i==2 and j==2018:
            pass
        else:
            globals()["crime_data_q{}_{}".format(i,j)]=globals()["crime_data_q{}_{}".format(i,j)].rename(columns=globals()["crime_data_q{}_{}".format(i,j)].iloc[2]).drop(index=[0,1,2], axis=0)
            

for i in range(1,4):
    globals()["crime_data_q{}_{}".format(i,2015)]=globals()["crime_data_q{}_{}".format(i,2015)].rename(columns=globals()["crime_data_q{}_{}".format(i,2015)].iloc[3]).drop(index=[0,1,2,3], axis=0)
    
    
globals()["crime_data_q{}_{}".format(4,2015)]=globals()["crime_data_q{}_{}".format(4,2015)].rename(columns=globals()["crime_data_q{}_{}".format(4,2015)].iloc[2]).drop(index=[0,1,2], axis=0)

globals()["crime_data_q{}_{}".format(2,2018)]=globals()["crime_data_q{}_{}".format(2,2018)].rename(columns=globals()["crime_data_q{}_{}".format(2,2018)].iloc[3]).drop(index=[0,1,2,3], axis=0)


globals()["crime_data_q{}_{}".format(1,2019)]=globals()["crime_data_q{}_{}".format(1,2019)].drop(index=[1158], axis=0)
globals()["crime_data_q{}_{}".format(1,2016)]=globals()["crime_data_q{}_{}".format(1,2016)].drop(index=[1158], axis=0)

for i in range(1,5):
    for j in range(2015,2021):
        globals()["crime_data_q{}_{}".format(i,j)].columns.values[4] = "MURDER"
        globals()["crime_data_q{}_{}".format(i,j)]["SIZE (ACRES)"] = globals()["crime_data_q{}_{}".format(i,j)]["SIZE (ACRES)"].fillna(0)
        globals()["crime_data_q{}_{}".format(i,j)]["SIZE (ACRES)"]=globals()["crime_data_q{}_{}".format(i,j)]["SIZE (ACRES)"].astype(float)
        globals()["crime_data_q{}_{}".format(i,j)]["MURDER"]=globals()["crime_data_q{}_{}".format(i,j)]["MURDER"].astype(int)
        globals()["crime_data_q{}_{}".format(i,j)]["RAPE"]=globals()["crime_data_q{}_{}".format(i,j)]["RAPE"].astype(int)
        globals()["crime_data_q{}_{}".format(i,j)]["ROBBERY"]=globals()["crime_data_q{}_{}".format(i,j)]["ROBBERY"].astype(int)
        globals()["crime_data_q{}_{}".format(i,j)]["FELONY ASSAULT"]=globals()["crime_data_q{}_{}".format(i,j)]["FELONY ASSAULT"].astype(int)
        globals()["crime_data_q{}_{}".format(i,j)]["BURGLARY"]=globals()["crime_data_q{}_{}".format(i,j)]["BURGLARY"].astype(int)
        globals()["crime_data_q{}_{}".format(i,j)]["GRAND LARCENY"]=globals()["crime_data_q{}_{}".format(i,j)]["GRAND LARCENY"].astype(int)
        globals()["crime_data_q{}_{}".format(i,j)]["GRAND LARCENY OF MOTOR VEHICLE"]=globals()["crime_data_q{}_{}".format(i,j)]["GRAND LARCENY OF MOTOR VEHICLE"].astype(int)
        globals()["crime_data_q{}_{}".format(i,j)]["TOTAL"]=globals()["crime_data_q{}_{}".format(i,j)]["TOTAL"].astype(int)

for i in range(1,5):
    for j in range(2015,2021):
        globals()["crime_data_q{}_{}".format(i,j)]=globals()["crime_data_q{}_{}".format(i,j)].sort_values(by="SIZE (ACRES)", ascending=False).reset_index(drop=True)

# %%
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values
#!conda install -c conda-forge folium=0.5.0 --yes
#import folium # map rendering library

# %%
address = 'FOREST PARK, NY'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of North York are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of North York are 40.7032623, -73.84609986721708.

# %%
for i in range(1,5):
    for j in range(2015,2021):
        print(globals()["crime_data_q{}_{}".format(i,j)].dtypes, i, j)
# Out:
# PARK                               object
# BOROUGH                            object
# SIZE (ACRES)                      float64
# CATEGORY                           object
# MURDER                             object
# RAPE                                int64
# ROBBERY                             int64
# FELONY ASSAULT                      int64
# BURGLARY                            int64
# GRAND LARCENY                       int64
# GRAND LARCENY OF MOTOR VEHICLE      int64
# TOTAL                               int64
# Murder                              int64
# dtype: object 1 2015
# PARK                               object
# BOROUGH                            object
# SIZE (ACRES)                      float64
# CATEGORY                           object
# MURDER                             object
# RAPE                                int64
# ROBBERY                             int64
# FELONY ASSAULT                      int64
# BURGLARY                            int64
# GRAND LARCENY                       int64
# GRAND LARCENY OF MOTOR VEHICLE      int64
# TOTAL                               int64
# Murder                              int64
# dtype: object 1 2016
# PARK                               object
# BOROUGH                            object
# SIZE (ACRES)                      float64
# CATEGORY                           object
# MURDER                             object
# RAPE                                int64
# ROBBERY                             int64
# FELONY ASSAULT                      int64
# BURGLARY                            int64
# GRAND LARCENY                       int64
# GRAND LARCENY OF MOTOR VEHICLE      int64
# TOTAL                               int64
# Murder                              int64
# dtype: object 1 2017
# PARK                               object
# BOROUGH                            object
# SIZE (ACRES)                      float64
# CATEGORY                           object
# MURDER                             object
# RAPE                                int64
# ROBBERY                             int64
# FELONY ASSAULT                      int64
# BURGLARY                            int64
# GRAND LARCENY                       int64
# GRAND LARCENY OF MOTOR VEHICLE      int64
# TOTAL                               int64
# Murder                              int64
# dtype: object 1 2018
# PARK                               object
# BOROUGH                            object
# SIZE (ACRES)                      float64
# CATEGORY                           object
# MURDER                             object
# RAPE                                int64
# ROBBERY                             int64
# FELONY ASSAULT                      int64
# BURGLARY                            int64
# GRAND LARCENY                       int64
# GRAND LARCENY OF MOTOR VEHICLE      int64
# TOTAL                               int64
# Murder                              int64
# dtype: object 1 2019
# PARK                               object
# BOROUGH                            object
# SIZE (ACRES)                      float64
# CATEGORY                           object
# MURDER                             object
# RAPE                                int64
# ROBBERY                             int64
# FELONY ASSAULT                      int64
# BURGLARY                            int64
# GRAND LARCENY                       int64
# GRAND LARCENY OF MOTOR VEHICLE      int64
# TOTAL                               int64
# Murder                              int64
# dtype: object 1 2020
# PARK                               object
# BOROUGH                            object
# SIZE (ACRES)                      float64
# CATEGORY                           object
# MURDER                             object
# RAPE                                int64
# ROBBERY                             int64
# FELONY ASSAULT                      int64
# BURGLARY                            int64
# GRAND LARCENY                       int64
# GRAND LARCENY OF MOTOR VEHICLE      int64
# TOTAL                               int64
# Murder                              int64
# dtype: object 2 2015
# PARK                               object
# BOROUGH                            object
# SIZE (ACRES)                      float64
# CATEGORY                           object
# MURDER                             object
# RAPE                                int64
# ROBBERY                             int64
# FELONY ASSAULT                      int64
# BURGLARY                            int64
# GRAND LARCENY                       int64
# GRAND LARCENY OF MOTOR VEHICLE      int64
# TOTAL                               int64
# Murder                              int64
# dtype: object 2 2016
# PARK                               object
# BOROUGH                            object
# SIZE (ACRES)                      float64
# CATEGORY                           object
# MURDER                             object
# RAPE                                int64
# ROBBERY                             int64
# FELONY ASSAULT                      int64
# BURGLARY                            int64
# GRAND LARCENY                       int64
# GRAND LARCENY OF MOTOR VEHICLE      int64
# TOTAL                               int64
# Murder                              int64
# dtype: object 2 2017
# PARK                               object
# BOROUGH                            object
# SIZE (ACRES)                      float64
# CATEGORY                           object
# MURDER                             object
# RAPE                                int64
# ROBBERY                             int64
# FELONY ASSAULT                      int64
# BURGLARY                            int64
# GRAND LARCENY                       int64
# GRAND LARCENY OF MOTOR VEHICLE      int64
# TOTAL                               int64
# Murder                              int64
# dtype: object 2 2018
# PARK                               object
# BOROUGH                            object
# SIZE (ACRES)                      float64
# CATEGORY                           object
# MURDER                             object
# RAPE                                int64
# ROBBERY                             int64
# FELONY ASSAULT                      int64
# BURGLARY                            int64
# GRAND LARCENY                       int64
# GRAND LARCENY OF MOTOR VEHICLE      int64
# TOTAL                               int64
# Murder                              int64
# dtype: object 2 2019
# PARK                               object
# BOROUGH                            object
# SIZE (ACRES)                      float64
# CATEGORY                           object
# MURDER                             object
# RAPE                                int64
# ROBBERY                             int64
# FELONY ASSAULT                      int64
# BURGLARY                            int64
# GRAND LARCENY                       int64
# GRAND LARCENY OF MOTOR VEHICLE      int64
# TOTAL                               int64
# Murder                              int64
# dtype: object 2 2020
# PARK                               object
# BOROUGH                            object
# SIZE (ACRES)                      float64
# CATEGORY                           object
# MURDER                             object
# RAPE                                int64
# ROBBERY                             int64
# FELONY ASSAULT                      int64
# BURGLARY                            int64
# GRAND LARCENY                       int64
# GRAND LARCENY OF MOTOR VEHICLE      int64
# TOTAL                               int64
# Murder                              int64
# dtype: object 3 2015
# PARK                               object
# BOROUGH                            object
# SIZE (ACRES)                      float64
# CATEGORY                           object
# MURDER                             object
# RAPE                                int64
# ROBBERY                             int64
# FELONY ASSAULT                      int64
# BURGLARY                            int64
# GRAND LARCENY                       int64
# GRAND LARCENY OF MOTOR VEHICLE      int64
# TOTAL                               int64
# Murder                              int64
# dtype: object 3 2016
# PARK                               object
# BOROUGH                            object
# SIZE (ACRES)                      float64
# CATEGORY                           object
# MURDER                             object
# RAPE                                int64
# ROBBERY                             int64
# FELONY ASSAULT                      int64
# BURGLARY                            int64
# GRAND LARCENY                       int64
# GRAND LARCENY OF MOTOR VEHICLE      int64
# TOTAL                               int64
# Murder                              int64
# dtype: object 3 2017
# PARK                               object
# BOROUGH                            object
# SIZE (ACRES)                      float64
# CATEGORY                           object
# MURDER                             object
# RAPE                                int64
# ROBBERY                             int64
# FELONY ASSAULT                      int64
# BURGLARY                            int64
# GRAND LARCENY                       int64
# GRAND LARCENY OF MOTOR VEHICLE      int64
# TOTAL                               int64
# Murder                              int64
# dtype: object 3 2018
# PARK                               object
# BOROUGH                            object
# SIZE (ACRES)                      float64
# CATEGORY                           object
# MURDER                             object
# RAPE                                int64
# ROBBERY                             int64
# FELONY ASSAULT                      int64
# BURGLARY                            int64
# GRAND LARCENY                       int64
# GRAND LARCENY OF MOTOR VEHICLE      int64
# TOTAL                               int64
# Murder                              int64
# dtype: object 3 2019
# PARK                               object
# BOROUGH                            object
# SIZE (ACRES)                      float64
# CATEGORY                           object
# MURDER                             object
# RAPE                                int64
# ROBBERY                             int64
# FELONY ASSAULT                      int64
# BURGLARY                            int64
# GRAND LARCENY                       int64
# GRAND LARCENY OF MOTOR VEHICLE      int64
# TOTAL                               int64
# Murder                              int64
# dtype: object 3 2020
# PARK                               object
# BOROUGH                            object
# SIZE (ACRES)                      float64
# CATEGORY                           object
# MURDER                             object
# RAPE                                int64
# ROBBERY                             int64
# FELONY ASSAULT                      int64
# BURGLARY                            int64
# GRAND LARCENY                       int64
# GRAND LARCENY OF MOTOR VEHICLE      int64
# TOTAL                               int64
# Murder                              int64
# dtype: object 4 2015
# PARK                               object
# BOROUGH                            object
# SIZE (ACRES)                      float64
# CATEGORY                           object
# MURDER                             object
# RAPE                                int64
# ROBBERY                             int64
# FELONY ASSAULT                      int64
# BURGLARY                            int64
# GRAND LARCENY                       int64
# GRAND LARCENY OF MOTOR VEHICLE      int64
# TOTAL                               int64
# Murder                              int64
# dtype: object 4 2016
# PARK                               object
# BOROUGH                            object
# SIZE (ACRES)                      float64
# CATEGORY                           object
# MURDER                             object
# RAPE                                int64
# ROBBERY                             int64
# FELONY ASSAULT                      int64
# BURGLARY                            int64
# GRAND LARCENY                       int64
# GRAND LARCENY OF MOTOR VEHICLE      int64
# TOTAL                               int64
# Murder                              int64
# dtype: object 4 2017
# PARK                               object
# BOROUGH                            object
# SIZE (ACRES)                      float64
# CATEGORY                           object
# MURDER                             object
# RAPE                                int64
# ROBBERY                             int64
# FELONY ASSAULT                      int64
# BURGLARY                            int64
# GRAND LARCENY                       int64
# GRAND LARCENY OF MOTOR VEHICLE      int64
# TOTAL                               int64
# Murder                              int64
# dtype: object 4 2018
# PARK                               object
# BOROUGH                            object
# SIZE (ACRES)                      float64
# CATEGORY                           object
# MURDER                             object
# RAPE                                int64
# ROBBERY                             int64
# FELONY ASSAULT                      int64
# BURGLARY                            int64
# GRAND LARCENY                       int64
# GRAND LARCENY OF MOTOR VEHICLE      int64
# TOTAL                               int64
# Murder                              int64
# dtype: object 4 2019
# PARK                               object
# BOROUGH                            object
# SIZE (ACRES)                      float64
# CATEGORY                           object
# MURDER                             object
# RAPE                                int64
# ROBBERY                             int64
# FELONY ASSAULT                      int64
# BURGLARY                            int64
# GRAND LARCENY                       int64
# GRAND LARCENY OF MOTOR VEHICLE      int64
# TOTAL                               int64
# Murder                              int64
# dtype: object 4 2020

# %%
crime_data_q2_2016
# Out:
#                               PARK        BOROUGH  SIZE (ACRES)  \
# 0                  PELHAM BAY PARK  BRONX              2771.747
# 1               VAN CORTLANDT PARK  BRONX              1146.430
# 2     ROCKAWAY BEACH AND BOARDWALK  QUEENS             1072.564
# 3                  FRESHKILLS PARK  STATEN ISLAND       913.320
# 4     FLUSHING MEADOWS CORONA PARK  QUEENS              897.690
# ...                            ...            ...           ...
# 1150              MOHEGAN TRIANGLE  BRONX                 0.096
# 1151    PLAYGROUND OF THE AMERICAS  MANHATTAN             0.079
# 1152     PRIVATE WILLIAM GRAY PARK  QUEENS                0.069
# 1153         ADRIENNE'S PLAYGROUND  MANHATTAN             0.000
# 1154                         TOTAL            NaN         0.000
#
#                            CATEGORY  MURDER  RAPE  ROBBERY  FELONY ASSAULT  \
# 0                ONE ACRE OR LARGER       0     0        0               1
# 1                ONE ACRE OR LARGER       0     0        1               4
# 2                ONE ACRE OR LARGER       0     0        0               0
# 3                ONE ACRE OR LARGER       0     0        0               0
# 4                ONE ACRE OR LARGER       0     0        3               1
# ...                             ...     ...   ...      ...             ...
# 1150  PLAYGROUND LESS THAN ONE ACRE       0     0        0               0
# 1151  PLAYGROUND LESS THAN ONE ACRE       0     0        0               0
# 1152  PLAYGROUND LESS THAN ONE ACRE       0     0        0               0
# 1153  PLAYGROUND LESS THAN ONE ACRE       0     0        0               0
# 1154                            NaN       1     4      117              73
#
#       BURGLARY  GRAND LARCENY  GRAND LARCENY OF MOTOR VEHICLE  TOTAL
# 0            0              2                               0      3
# 1            0              1                               0      6
# 2            0              2                               0      2
# 3            0              0                               0      0
# 4            0             21                               0     25
# ...        ...            ...                             ...    ...
# 1150         0              0                               0      0
# 1151         0              0                               0      0
# 1152         0              0                               0      0
# 1153         0              0                               0      0
# 1154         4            152                               1    352
#
# [1155 rows x 12 columns]
